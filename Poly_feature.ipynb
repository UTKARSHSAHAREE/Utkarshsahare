# %% [markdown]
# <a href="https://colab.research.google.com/github/UTKARSHSAHAREE/Utkarshsahare/blob/main/Poly_feature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'/content/PolynomialRegressiondata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  15 non-null     int64
#  1   Pressure     15 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 368.0 bytes

# %%
df.isnull()
# Out:
#     Temperature  Pressure
# 0         False     False
# 1         False     False
# 2         False     False
# 3         False     False
# 4         False     False
# 5         False     False
# 6         False     False
# 7         False     False
# 8         False     False
# 9         False     False
# 10        False     False
# 11        False     False
# 12        False     False
# 13        False     False
# 14        False     False

# %%
df.columns
# Out:
# Index(['Temperature', 'Pressure'], dtype='object')

# %%
x=df['Temperature'].values
y=df['Pressure'].values

# %%
#from sklearn.model_selection import train_test_split
#x_train,  x_test, y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x=x.reshape(-1,1)
#x_test=x_test.reshape(-1,1)
#y_train=y_train.reshape(-1,1)
y=y.reshape(-1,1)

# %%
df.corr()
# Out:
#              Temperature  Pressure
# Temperature     1.000000  0.890825
# Pressure        0.890825  1.000000

# %%
plt.scatter(x,y,c="c",marker="x")
plt.grid()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,c="c",marker="x")
plt.plot(x,model.predict(x),color="violet")
plt.grid()
plt.show()

# %%
model.predict(x)
# Out:
# array([[-2.74626202],
#        [-2.44611624],
#        [-2.14597046],
#        [-1.5456789 ],
#        [-0.34509578],
#        [ 0.85548734],
#        [ 2.05607045],
#        [ 2.65636201],
#        [ 3.25665357],
#        [ 3.85694513],
#        [ 4.45723669],
#        [ 6.25811137],
#        [ 8.05898604],
#        [11.06044384],
#        [12.26102695]])

# %% [markdown]
# # THIS IS UNDERFITTED AND BIASED HENCE USIN POLYNOMIAL REGRESSION

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)

# %%
x2=poly.fit_transform(x)

# %%
x2.shape
# Out:
# (15, 3)

# %%
model2=LinearRegression()

# %%
model2.fit(x2,y)
# Out:
# LinearRegression()

# %%
x2
# Out:
# array([[1.00e+00, 0.00e+00, 0.00e+00],
#        [1.00e+00, 5.00e+00, 2.50e+01],
#        [1.00e+00, 1.00e+01, 1.00e+02],
#        [1.00e+00, 2.00e+01, 4.00e+02],
#        [1.00e+00, 4.00e+01, 1.60e+03],
#        [1.00e+00, 6.00e+01, 3.60e+03],
#        [1.00e+00, 8.00e+01, 6.40e+03],
#        [1.00e+00, 9.00e+01, 8.10e+03],
#        [1.00e+00, 1.00e+02, 1.00e+04],
#        [1.00e+00, 1.10e+02, 1.21e+04],
#        [1.00e+00, 1.20e+02, 1.44e+04],
#        [1.00e+00, 1.50e+02, 2.25e+04],
#        [1.00e+00, 1.80e+02, 3.24e+04],
#        [1.00e+00, 2.30e+02, 5.29e+04],
#        [1.00e+00, 2.50e+02, 6.25e+04]])

# %%
plt.scatter(x,y,c="c",marker="x")
plt.plot(x,model2.predict(x2),color="violet")
plt.grid()
plt.show()

# %%
poly2=PolynomialFeatures(degree=3)

# %%
x3=poly2.fit_transform(x)

# %%
x3.shape
# Out:
# (15, 4)

# %%
model3=LinearRegression()

# %%
model3.fit(x3,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,c="c",marker="x")
plt.plot(x,model3.predict(x3),color="violet")
plt.grid()
plt.show()
